# %%
import pandas as pd
import numpy as np
import timeit

def test_solutions(*solutions, df, number):
    for idx, solution in enumerate(solutions):
        def timed_solution():
            solution(df.copy())
            
        time = timeit.timeit(timed_solution, number=number)
        print(f"Solution {idx + 1} Time: {time:.6f} seconds")

# %%
df = pd.DataFrame([
    {"ord_no":70001.0, "purch_amt":150.5, "ord_date":"2012-10-05", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":270.65, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70002.0, "purch_amt":65.26, "ord_date":None, "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70004.0, "purch_amt":110.5, "ord_date":"2012-08-17", "customer_id":3003, "salesman_id":None},
    {"ord_no":None, "purch_amt":948.5, "ord_date":"2012-09-10", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":70005.0, "purch_amt":2400.6, "ord_date":"2012-07-27", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":None, "purch_amt":5760.0, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70010.0, "purch_amt":1983.43, "ord_date":"2012-10-10", "customer_id":3004, "salesman_id":None},
    {"ord_no":70003.0, "purch_amt":2480.4, "ord_date":"2012-10-10", "customer_id":3003, "salesman_id":5003.0},
    {"ord_no":70012.0, "purch_amt":250.45, "ord_date":"2012-06-27", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":75.29, "ord_date":"2012-08-17", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70013.0, "purch_amt":3045.6, "ord_date":"2012-04-25", "customer_id":3001, "salesman_id":None}
])
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26        None         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %% [markdown]
# ##### 1. Write a Pandas program to detect missing values of a given DataFrame. Display True or False.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0, "purch_amt":150.5, "ord_date":"2012-10-05", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":270.65, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70002.0, "purch_amt":65.26, "ord_date":None, "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70004.0, "purch_amt":110.5, "ord_date":"2012-08-17", "customer_id":3003, "salesman_id":None},
    {"ord_no":None, "purch_amt":948.5, "ord_date":"2012-09-10", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":70005.0, "purch_amt":2400.6, "ord_date":"2012-07-27", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":None, "purch_amt":5760.0, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70010.0, "purch_amt":1983.43, "ord_date":"2012-10-10", "customer_id":3004, "salesman_id":None},
    {"ord_no":70003.0, "purch_amt":2480.4, "ord_date":"2012-10-10", "customer_id":3003, "salesman_id":5003.0},
    {"ord_no":70012.0, "purch_amt":250.45, "ord_date":"2012-06-27", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":75.29, "ord_date":"2012-08-17", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70013.0, "purch_amt":3045.6, "ord_date":"2012-04-25", "customer_id":3001, "salesman_id":None}
])
display(df.isna())
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# ##### 2. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0, "purch_amt":150.5, "ord_date":"2012-10-05", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":270.65, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70002.0, "purch_amt":65.26, "ord_date":None, "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70004.0, "purch_amt":110.5, "ord_date":"2012-08-17", "customer_id":3003, "salesman_id":None},
    {"ord_no":None, "purch_amt":948.5, "ord_date":"2012-09-10", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":70005.0, "purch_amt":2400.6, "ord_date":"2012-07-27", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":None, "purch_amt":5760.0, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70010.0, "purch_amt":1983.43, "ord_date":"2012-10-10", "customer_id":3004, "salesman_id":None},
    {"ord_no":70003.0, "purch_amt":2480.4, "ord_date":"2012-10-10", "customer_id":3003, "salesman_id":5003.0},
    {"ord_no":70012.0, "purch_amt":250.45, "ord_date":"2012-06-27", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":75.29, "ord_date":"2012-08-17", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70013.0, "purch_amt":3045.6, "ord_date":"2012-04-25", "customer_id":3001, "salesman_id":None}
])
display(df.isna().any())
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %% [markdown]
# ##### 3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0, "purch_amt":150.5, "ord_date":"2012-10-05", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":270.65, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70002.0, "purch_amt":65.26, "ord_date":None, "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70004.0, "purch_amt":110.5, "ord_date":"2012-08-17", "customer_id":3003, "salesman_id":None},
    {"ord_no":None, "purch_amt":948.5, "ord_date":"2012-09-10", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":70005.0, "purch_amt":2400.6, "ord_date":"2012-07-27", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":None, "purch_amt":5760.0, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70010.0, "purch_amt":1983.43, "ord_date":"2012-10-10", "customer_id":3004, "salesman_id":None},
    {"ord_no":70003.0, "purch_amt":2480.4, "ord_date":"2012-10-10", "customer_id":3003, "salesman_id":5003.0},
    {"ord_no":70012.0, "purch_amt":250.45, "ord_date":"2012-06-27", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":75.29, "ord_date":"2012-08-17", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70013.0, "purch_amt":3045.6, "ord_date":"2012-04-25", "customer_id":3001, "salesman_id":None}
])
display(df.isna().sum())
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# ##### 4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0, "purch_amt":150.5, "ord_date":"2012-10-05", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":270.65, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70002.0, "purch_amt":65.26, "ord_date":None, "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70004.0, "purch_amt":110.5, "ord_date":"2012-08-17", "customer_id":3003, "salesman_id":None},
    {"ord_no":None, "purch_amt":948.5, "ord_date":"2012-09-10", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":70005.0, "purch_amt":2400.6, "ord_date":"2012-07-27", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":None, "purch_amt":5760.0, "ord_date":"2012-09-10", "customer_id":3001, "salesman_id":5001.0},
    {"ord_no":70010.0, "purch_amt":1983.43, "ord_date":"2012-10-10", "customer_id":3004, "salesman_id":None},
    {"ord_no":70003.0, "purch_amt":2480.4, "ord_date":"2012-10-10", "customer_id":3003, "salesman_id":5003.0},
    {"ord_no":70012.0, "purch_amt":250.45, "ord_date":"2012-06-27", "customer_id":3002, "salesman_id":5002.0},
    {"ord_no":None, "purch_amt":75.29, "ord_date":"2012-08-17", "customer_id":3001, "salesman_id":5003.0},
    {"ord_no":70013.0, "purch_amt":3045.6, "ord_date":"2012-04-25", "customer_id":3001, "salesman_id":None}
])
display(df.fillna('Value'))
# Out:
#      ord_no  purch_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50  2012-10-05         3002      5002.0
# 1     Value     270.65  2012-09-10         3001      5003.0
# 2   70002.0      65.26       Value         3001      5001.0
# 3   70004.0     110.50  2012-08-17         3003       Value
# 4     Value     948.50  2012-09-10         3002      5002.0
# 5   70005.0    2400.60  2012-07-27         3001      5001.0
# 6     Value    5760.00  2012-09-10         3001      5001.0
# 7   70010.0    1983.43  2012-10-10         3004       Value
# 8   70003.0    2480.40  2012-10-10         3003      5003.0
# 9   70012.0     250.45  2012-06-27         3002      5002.0
# 10    Value      75.29  2012-08-17         3001      5003.0
# 11  70013.0    3045.60  2012-04-25         3001       Value

# %%
df = pd.DataFrame({
    'ord_no':[70001,np.nan,70002,70004,np.nan,70005,"--",70010,70003,70012,np.nan,70013],
    'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,"?",12.43,2480.4,250.45, 3045.6],
    'ord_date': ['?','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
    'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,"--",3002,3001,3001],
    'salesman_id':[5002,5003,"?",5001,np.nan,5002,5001,"?",5003,5002,5003,"--"]
})
display(df.info())
result = df.replace(["?", "--"], np.nan)
display(result)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ord_no       9 non-null      object
#  1   purch_amt    12 non-null     object
#  2   ord_date     11 non-null     object
#  3   customer_id  12 non-null     object
#  4   salesman_id  11 non-null     object
# dtypes: object(5)
# memory usage: 612.0+ bytes
# None
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_16712\2284581478.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = df.replace(["?", "--"], np.nan)
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN       3002.0       5002.0
# ...

# %% [markdown]
# ##### 5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt':[150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45,  75.29, 3045.6], 
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'], 
    'customer_id':[3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001], 
    'salesman_id':[5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})
df.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %% [markdown]
# ##### 6. Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt':[150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45,  75.29, 3045.6], 
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'], 
    'customer_id':[3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001], 
    'salesman_id':[5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})
df.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# ##### 7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
    'purch_amt':[np.nan,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
    'ord_date': [np.nan,'2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
    'customer_id':[np.nan,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001]
})
df.dropna(how='all')
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# ##### 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})
display(df[df.isna().sum(axis=1) > 1])

display(df.dropna(thresh=2))
# Out:
#     ord_no  purch_amt ord_date  customer_id
# 0      NaN        NaN      NaN          NaN
# 3      NaN        NaN      NaN          NaN
# 11     NaN        NaN      NaN          NaN
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %% [markdown]
# ##### 9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})
display(df[~df['ord_no'].isna()])

display(df.dropna(subset=['ord_no']))
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 2  70002.0      65.26         NaN       3001.0
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0
#     ord_no  purch_amt    ord_date  customer_id
# 2  70002.0      65.26         NaN       3001.0
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# ##### 10. Write a Pandas program to keep the valid entries of a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})
df.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# ##### 11. Write a Pandas program to calculate the total number of missing values in a DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})
print("Total number of missing values of the said DataFrame:")
print(df.isna().sum().sum())
# Out:
# Total number of missing values of the said DataFrame:
# 17

# %% [markdown]
# ##### 12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})

df['ord_no'] = df['ord_no'].fillna(0)
display(df)
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       0.0        NaN         NaN          NaN
# 1       0.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       0.0        NaN         NaN          NaN
# 4       0.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       0.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      0.0      75.29  2012-08-17       3001.0
# 11      0.0        NaN         NaN          NaN

# %% [markdown]
# ##### 13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.

# %%
df = pd.DataFrame({
    'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
    'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
    'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
    'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]
})

display(df)
result = df.ffill()
display(result)
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26  2012-09-10       3001.0
# 3   70002.0      65.26  2012-09-10       3001.0
# 4   70002.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# ...

# %% [markdown]
# ##### 14. Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
display(df)
result = df.fillna({'purch_amt': df['purch_amt'].mean()})
display(result)
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN        None         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ...

# %% [markdown]
# ##### 15. Write a Pandas program to interpolate the missing values using the Linear Interpolation method in a given DataFrame.
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting using linear polynomials to construct new data points within the range of a discrete set of known data points.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
display(df)
df['purch_amt'] = df['purch_amt'].interpolate()
display(df)
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN        None         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ...

# %% [markdown]
# ##### 16. Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
df['purch_amt'].isna().sum()
# Out:
# np.int64(3)

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
df['purch_amt'].value_counts(dropna=False).loc[np.nan]
# Out:
# np.int64(3)

# %%
count = 1000000
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
] * count)

def solution_1(df):
    return df['purch_amt'].isna().sum()

def solution_2(df):
    return df['purch_amt'].value_counts(dropna=False).loc[np.nan]

test_solutions(solution_1, solution_2, df=df, number=1)
# Out:
# Solution 1 Time: 0.203382 seconds
# Solution 2 Time: 0.331739 seconds

# %% [markdown]
# ##### 17. Write a Pandas program to count the missing values in a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
df.isna().sum().sum()
# Out:
# np.int64(14)

# %% [markdown]
# ##### 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])

print(df.loc[df['ord_no'].isna()].index.values)

print(df['ord_no'].isnull().to_numpy().nonzero()[0])
# Out:
# Index([1, 4, 6, 10], dtype='int64')
# [ 1  4  6 10]

# %%
count = 1000000
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
] * count)

def solution_1(df):
    df.loc[df['ord_no'].isna()].index.values

def solution_2(df):
    df['ord_no'].isnull().to_numpy().nonzero()[0]

test_solutions(solution_1, solution_2, df=df, number=1)
# Out:
# Solution 1 Time: 0.330370 seconds
# Solution 2 Time: 0.195399 seconds

# %% [markdown]
# ##### 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
display(df)
most_freq = df.mode().iloc[0]
display(most_freq)
df.fillna(most_freq)
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN        None         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ord_no            70001.0
# ...

# %% [markdown]
# ##### 20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.

# %%
df = pd.DataFrame([
    {"ord_no":70001.0,"purch_amt":150.5,"sale_amt":10.5,"ord_date":"2012-10-05","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":None,"sale_amt":20.65,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70002.0,"purch_amt":65.26,"sale_amt":None,"ord_date":None,"customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70004.0,"purch_amt":110.5,"sale_amt":11.5,"ord_date":"2012-08-17","customer_id":3003,"salesman_id":None},
    {"ord_no":None,"purch_amt":948.5,"sale_amt":98.5,"ord_date":"2012-09-10","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":70005.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-07-27","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":None,"purch_amt":5760.0,"sale_amt":57.0,"ord_date":"2012-09-10","customer_id":3001,"salesman_id":5001.0},
    {"ord_no":70010.0,"purch_amt":1983.43,"sale_amt":19.43,"ord_date":"2012-10-10","customer_id":3004,"salesman_id":None},
    {"ord_no":70003.0,"purch_amt":None,"sale_amt":None,"ord_date":"2012-10-10","customer_id":3003,"salesman_id":5003.0},
    {"ord_no":70012.0,"purch_amt":250.45,"sale_amt":25.45,"ord_date":"2012-06-27","customer_id":3002,"salesman_id":5002.0},
    {"ord_no":None,"purch_amt":75.29,"sale_amt":75.29,"ord_date":"2012-08-17","customer_id":3001,"salesman_id":5003.0},
    {"ord_no":70013.0,"purch_amt":3045.6,"sale_amt":35.6,"ord_date":"2012-04-25","customer_id":3001,"salesman_id":None}
])
# Out:
# Object `df.heatmap` not found.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
plt.figure(figsize=(16,10))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
plt.show()
